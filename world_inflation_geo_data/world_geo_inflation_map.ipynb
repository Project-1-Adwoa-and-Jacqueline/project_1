# %%
# ignore warnings
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#imports
from pathlib import Path
import datetime as dt
import hvplot.pandas
import pandas as pd
from shapely.geometry import Polygon
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import geoviews as gv
import geoviews.feature as gf
from geoviews import dim, opts
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Lat/Lon CSV Cleaning

# %%
# name csv path
world_geo_path = Path("world_geo_data.csv")

# create dataframe from csv
world_geo_df =pd.read_csv(world_geo_path)

world_geo_df.head()
# Out:
#   country_code   latitude  longitude               country usa_state_code  \
# 0           AD  42.546245   1.601554               Andorra             AK
# 1           AE  23.424076  53.847818  United Arab Emirates             AL
# 2           AF  33.939110  67.709953           Afghanistan             AR
# 3           AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4           AI  18.220554 -63.068615              Anguilla             CA
#
#    usa_state_latitude  usa_state_longitude   usa_state
# 0           63.588753          -154.493062      Alaska
# 1           32.318231           -86.902298     Alabama
# 2           35.201050           -91.831833    Arkansas
# 3           34.048928          -111.093731     Arizona
# 4           36.778261          -119.417932  California

# %%
# rename columns for clarity and consistency
world_geo_df.rename(columns={"country_code": "alpha-2"}, inplace=True)

# drop unnecessary columns
world_geo_df.drop(labels=["usa_state_code",
    "usa_state_latitude",
    "usa_state_longitude",
    "usa_state"
    ], axis=1, inplace=True)

world_geo_df.head()
# Out:
#   alpha-2   latitude  longitude               country
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
# check for nulls
nulls = world_geo_df.isnull().any(axis=1)
null_rows = world_geo_df[nulls]
display(null_rows)
# Out:
#     alpha-2  latitude  longitude                      country
# 156     NaN -22.95764   18.49041                      Namibia
# 226      UM       NaN        NaN  U.S. Minor Outlying Islands

# %%
# fix alpha-2 for Namibia
world_geo_df.at[156, "alpha-2"] = "NA"

# check
print(world_geo_df.at[156, "alpha-2"])

# delete row for US Minor Outlying Islands because their geography is not bound by lon/lat
world_geo_df.drop(226, inplace=True)

# check
nulls = world_geo_df.isnull().any(axis=1)
null_rows = world_geo_df[nulls]
display(null_rows)
# Out:
# NA
# Empty DataFrame
# Columns: [alpha-2, latitude, longitude, country]
# Index: []

# %%
# check data types
world_geo_df.dtypes
# Out:
# alpha-2       object
# latitude     float64
# longitude    float64
# country       object
# dtype: object

# %% [markdown]
# ### World Inflation CSV Cleaning

# %%
# name csv path
world_inflation_path = Path("world_inflation_data.csv")

# create dataframe from csv, skipping blank rows and naming the header
world_inflation_df =pd.read_csv(world_inflation_path, header=2, skiprows=[0, 1])

world_inflation_df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name  Indicator Code  1960  1961  1962  \
# 0  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 1  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 2  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
#
#    1963  1964  1965  ...      2013      2014      2015       2016       2017  \
# 0   NaN   NaN   NaN  ... -2.372065  0.421441  0.474764  -0.931196  -1.028282
# 1   NaN   NaN   NaN  ...  5.750981  5.370290  5.245878   6.571396   6.399343
# 2   NaN   NaN   NaN  ...  7.385772  4.673996 -0.661709   4.383892   4.975952
# 3   NaN   NaN   NaN  ...  2.439201  1.768436  2.130817   1.487416   1.764635
# 4   NaN   NaN   NaN  ...  8.777814  7.280387  9.353840  30.698958  29.842578
#
#         2018       2019       2020       2021       2022
# 0   3.626041   4.257462        NaN        NaN        NaN
# 1   4.720811   4.653665   7.321106   6.824727  10.773751
# 2   0.626149   2.302373        NaN        NaN        NaN
# 3   1.784050   1.760112   2.437609   3.653533   7.967574
# 4  19.630594  17.079704  22.271564  25.754266        NaN
#
# [5 rows x 67 columns]

# %%
# drop unnecessary columns
world_inflation_df.drop(columns=["Indicator Name", "Indicator Code"], inplace=True)

# rename country_code column for clarity and consistency
world_inflation_df.rename(columns={"Country Code": "alpha-3", "Country Name":"country"}, inplace=True)

world_inflation_df.head()
# Out:
#                        country alpha-3  1960  1961  1962  1963  1964  1965  \
# 0                        Aruba     ABW   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Africa Eastern and Southern     AFE   NaN   NaN   NaN   NaN   NaN   NaN
# 2                  Afghanistan     AFG   NaN   NaN   NaN   NaN   NaN   NaN
# 3   Africa Western and Central     AFW   NaN   NaN   NaN   NaN   NaN   NaN
# 4                       Angola     AGO   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1966  1967  ...      2013      2014      2015       2016       2017  \
# 0   NaN   NaN  ... -2.372065  0.421441  0.474764  -0.931196  -1.028282
# 1   NaN   NaN  ...  5.750981  5.370290  5.245878   6.571396   6.399343
# 2   NaN   NaN  ...  7.385772  4.673996 -0.661709   4.383892   4.975952
# 3   NaN   NaN  ...  2.439201  1.768436  2.130817   1.487416   1.764635
# 4   NaN   NaN  ...  8.777814  7.280387  9.353840  30.698958  29.842578
#
#         2018       2019       2020       2021       2022
# 0   3.626041   4.257462        NaN        NaN        NaN
# 1   4.720811   4.653665   7.321106   6.824727  10.773751
# 2   0.626149   2.302373        NaN        NaN        NaN
# 3   1.784050   1.760112   2.437609   3.653533   7.967574
# 4  19.630594  17.079704  22.271564  25.754266        NaN
#
# [5 rows x 65 columns]

# %%
# check data types
world_inflation_df.dtypes
# Out:
# country     object
# alpha-3     object
# 1960       float64
# 1961       float64
# 1962       float64
#             ...
# 2018       float64
# 2019       float64
# 2020       float64
# 2021       float64
# 2022       float64
# Length: 65, dtype: object

# %% [markdown]
# ### ISO2/ISO3 CSV Cleaning

# %%
# path
country_info_path = Path("country_info.csv")

# create dataframe from csv
country_info_df = pd.read_csv(country_info_path)

country_info_df.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
# keep necessary columns
country_info_df = country_info_df[["name", "alpha-2", "alpha-3"]]

# change column names for consistency and clarity
country_info_df.rename(columns={"name":"country"}, inplace=True)

country_info_df.head()
# Out:
#           country alpha-2 alpha-3
# 0     Afghanistan      AF     AFG
# 1   Åland Islands      AX     ALA
# 2         Albania      AL     ALB
# 3         Algeria      DZ     DZA
# 4  American Samoa      AS     ASM

# %%
# check for nulls
nulls = country_info_df.isnull().any(axis=1)
null_rows = country_info_df[nulls]
display(null_rows)
# Out:
#      country alpha-2 alpha-3
# 153  Namibia     NaN     NAM

# %%
# fix issue with Namibia alpha-2 (NaN)
country_info_df.at[153, "alpha-2"] = "NA"
# check
print(country_info_df.at[153, "alpha-2"])
# Out:
# NA

# %%
# check datatypes
country_info_df.dtypes
# Out:
# country    object
# alpha-2    object
# alpha-3    object
# dtype: object

# %% [markdown]
# # Combining 3 Dataframes

# %%
# view dataframes together
display(country_info_df.head())
display(world_inflation_df.head())
display(world_geo_df.head())
# Out:
#           country alpha-2 alpha-3
# 0     Afghanistan      AF     AFG
# 1   Åland Islands      AX     ALA
# 2         Albania      AL     ALB
# 3         Algeria      DZ     DZA
# 4  American Samoa      AS     ASM
#                        country alpha-3  1960  1961  1962  1963  1964  1965  \
# 0                        Aruba     ABW   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Africa Eastern and Southern     AFE   NaN   NaN   NaN   NaN   NaN   NaN
# 2                  Afghanistan     AFG   NaN   NaN   NaN   NaN   NaN   NaN
# 3   Africa Western and Central     AFW   NaN   NaN   NaN   NaN   NaN   NaN
# 4                       Angola     AGO   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1966  1967  ...      2013      2014      2015       2016       2017  \
# 0   NaN   NaN  ... -2.372065  0.421441  0.474764  -0.931196  -1.028282
# 1   NaN   NaN  ...  5.750981  5.370290  5.245878   6.571396   6.399343
# 2   NaN   NaN  ...  7.385772  4.673996 -0.661709   4.383892   4.975952
# 3   NaN   NaN  ...  2.439201  1.768436  2.130817   1.487416   1.764635
# 4   NaN   NaN  ...  8.777814  7.280387  9.353840  30.698958  29.842578
#
#         2018       2019       2020       2021       2022
# 0   3.626041   4.257462        NaN        NaN        NaN
# 1   4.720811   4.653665   7.321106   6.824727  10.773751
# 2   0.626149   2.302373        NaN        NaN        NaN
# 3   1.784050   1.760112   2.437609   3.653533   7.967574
# 4  19.630594  17.079704  22.271564  25.754266        NaN
#
# [5 rows x 65 columns]
#   alpha-2   latitude  longitude               country
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
# merge dataframes (merge instead of join because of dissimilar indexes)
combined_df = country_info_df.merge(world_geo_df, how="inner", on="alpha-2")
combined_df = combined_df.merge(world_inflation_df, how="inner", on="alpha-3")
combined_df
# Out:
#                     country_x alpha-2 alpha-3   latitude   longitude  \
# 0                 Afghanistan      AF     AFG  33.939110   67.709953
# 1                     Albania      AL     ALB  41.153332   20.168331
# 2                     Algeria      DZ     DZA  28.033886    1.659626
# 3              American Samoa      AS     ASM -14.270972 -170.132217
# 4                     Andorra      AD     AND  42.546245    1.601554
# ..                        ...     ...     ...        ...         ...
# 206  Virgin Islands (British)      VG     VGB  18.420695  -64.639968
# 207     Virgin Islands (U.S.)      VI     VIR  18.335765  -64.896335
# 208                     Yemen      YE     YEM  15.552727   48.516388
# 209                    Zambia      ZM     ZMB -13.133897   27.849332
# 210                  Zimbabwe      ZW     ZWE -19.015438   29.154857
#
#                   country_y                 country  1960  1961  1962  ...  \
# 0               Afghanistan             Afghanistan   NaN   NaN   NaN  ...
# 1                   Albania                 Albania   NaN   NaN   NaN  ...
# 2                   Algeria                 Algeria   NaN   NaN   NaN  ...
# 3            American Samoa          American Samoa   NaN   NaN   NaN  ...
# 4                   Andorra                 Andorra   NaN   NaN   NaN  ...
# ..                      ...                     ...   ...   ...   ...  ...
# 206  British Virgin Islands  British Virgin Islands   NaN   NaN   NaN  ...
# 207     U.S. Virgin Islands   Virgin Islands (U.S.)   NaN   NaN   NaN  ...
# 208                   Yemen             Yemen, Rep.   NaN   NaN   NaN  ...
# 209                  Zambia                  Zambia   NaN   NaN   NaN  ...
# 210                Zimbabwe                Zimbabwe   NaN   NaN   NaN  ...
#
#           2013      2014       2015       2016      2017       2018  \
# 0     7.385772  4.673996  -0.661709   4.383892  4.975952   0.626149
# 1     1.937621  1.625865   1.896174   1.275432  1.986661   2.028060
# 2     3.254239  2.916927   4.784447   6.397695  5.591116   4.269990
# 3          NaN       NaN        NaN        NaN       NaN        NaN
# 4          NaN       NaN        NaN        NaN       NaN        NaN
# ..         ...       ...        ...        ...       ...        ...
# 206        NaN       NaN        NaN        NaN       NaN        NaN
# 207        NaN       NaN        NaN        NaN       NaN        NaN
# 208  10.968442  8.104726        NaN        NaN       NaN        NaN
# 209   6.977676  7.806876  10.110593  17.869730  6.577312   7.494572
# 210   1.634950 -0.197785  -2.430968  -1.543670  0.893962  10.618866
#
#            2019        2020       2021        2022
# 0      2.302373         NaN        NaN         NaN
# 1      1.411091    1.620887   2.041472    6.725203
# 2      1.951768    2.415131   7.226063    9.265516
# 3           NaN         NaN        NaN         NaN
# 4           NaN         NaN        NaN         NaN
# ..          ...         ...        ...         ...
# 206         NaN         NaN        NaN         NaN
# 207         NaN         NaN        NaN         NaN
# 208         NaN         NaN        NaN         NaN
# 209    9.150316   15.733060  22.020768   10.993204
# 210  255.304991  557.201817  98.546105  104.705171
#
# [211 rows x 70 columns]

# %%
# drop duplicate columns
combined_df.drop(columns= ["country_y", "country", "alpha-2", "alpha-3"], inplace=True)

# rename country_x
combined_df.rename(columns={"country_x":"country"}, inplace=True)

# assign index
combined_df.set_index("country", inplace=True)

# sort by index
combined_df.sort_index(inplace=True)

# check
combined_df
# Out:
#                            latitude   longitude  1960  1961  1962  1963  1964  \
# country
# Afghanistan               33.939110   67.709953   NaN   NaN   NaN   NaN   NaN
# Albania                   41.153332   20.168331   NaN   NaN   NaN   NaN   NaN
# Algeria                   28.033886    1.659626   NaN   NaN   NaN   NaN   NaN
# American Samoa           -14.270972 -170.132217   NaN   NaN   NaN   NaN   NaN
# Andorra                   42.546245    1.601554   NaN   NaN   NaN   NaN   NaN
# ...                             ...         ...   ...   ...   ...   ...   ...
# Virgin Islands (British)  18.420695  -64.639968   NaN   NaN   NaN   NaN   NaN
# Virgin Islands (U.S.)     18.335765  -64.896335   NaN   NaN   NaN   NaN   NaN
# Yemen                     15.552727   48.516388   NaN   NaN   NaN   NaN   NaN
# Zambia                   -13.133897   27.849332   NaN   NaN   NaN   NaN   NaN
# Zimbabwe                 -19.015438   29.154857   NaN   NaN   NaN   NaN   NaN
#
#                           1965  1966  1967  ...       2013      2014  \
# country                                     ...
# Afghanistan                NaN   NaN   NaN  ...   7.385772  4.673996
# Albania                    NaN   NaN   NaN  ...   1.937621  1.625865
# Algeria                    NaN   NaN   NaN  ...   3.254239  2.916927
# American Samoa             NaN   NaN   NaN  ...        NaN       NaN
# Andorra                    NaN   NaN   NaN  ...        NaN       NaN
# ...                        ...   ...   ...  ...        ...       ...
# Virgin Islands (British)   NaN   NaN   NaN  ...        NaN       NaN
# Virgin Islands (U.S.)      NaN   NaN   NaN  ...        NaN       NaN
# Yemen                      NaN   NaN   NaN  ...  10.968442  8.104726
# Zambia                     NaN   NaN   NaN  ...   6.977676  7.806876
# Zimbabwe                   NaN   NaN   NaN  ...   1.634950 -0.197785
#
#                                2015       2016      2017       2018  \
# country
# Afghanistan               -0.661709   4.383892  4.975952   0.626149
# Albania                    1.896174   1.275432  1.986661   2.028060
# Algeria                    4.784447   6.397695  5.591116   4.269990
# American Samoa                  NaN        NaN       NaN        NaN
# Andorra                         NaN        NaN       NaN        NaN
# ...                             ...        ...       ...        ...
# Virgin Islands (British)        NaN        NaN       NaN        NaN
# Virgin Islands (U.S.)           NaN        NaN       NaN        NaN
# Yemen                           NaN        NaN       NaN        NaN
# Zambia                    10.110593  17.869730  6.577312   7.494572
# Zimbabwe                  -2.430968  -1.543670  0.893962  10.618866
#
#                                 2019        2020       2021        2022
# country
# Afghanistan                 2.302373         NaN        NaN         NaN
# Albania                     1.411091    1.620887   2.041472    6.725203
# Algeria                     1.951768    2.415131   7.226063    9.265516
# American Samoa                   NaN         NaN        NaN         NaN
# Andorra                          NaN         NaN        NaN         NaN
# ...                              ...         ...        ...         ...
# Virgin Islands (British)         NaN         NaN        NaN         NaN
# Virgin Islands (U.S.)            NaN         NaN        NaN         NaN
# Yemen                            NaN         NaN        NaN         NaN
# Zambia                      9.150316   15.733060  22.020768   10.993204
# Zimbabwe                  255.304991  557.201817  98.546105  104.705171
#
# [211 rows x 65 columns]

# %%
combined_df.dtypes
# Out:
# latitude     float64
# longitude    float64
# 1960         float64
# 1961         float64
# 1962         float64
#               ...
# 2018         float64
# 2019         float64
# 2020         float64
# 2021         float64
# 2022         float64
# Length: 65, dtype: object

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# ### Dot Map

# %% [markdown]
# calculations

# %%
# isolate 2022 in new df
inflation_target_year_df = combined_df[["latitude", "longitude", "2022"]]
# rename column for map
inflation_target_year_df.rename(columns={"2022":"Inflation Rate (2022)"}, inplace=True)
# drop nulls
inflation_target_year_df.dropna(inplace=True)



# calculate mean inflation overall during a specified time period
mean_world_inflation =  combined_df.iloc[:,-10:]
mean_world_inflation = mean_world_inflation.mean(axis=1, skipna=True)

# add to df
inflation_target_year_df["Mean Inflation"] = mean_world_inflation


# calculate 2022 inflation as a percentage of mean inflation by country
percent_mean_world_inflation = (inflation_target_year_df / mean_world_inflation)

# new column for percent of mean for 2022 inflation
inflation_target_year_df["2022 Inflation as Percent of Mean Inflation (20 years)"] = round(((inflation_target_year_df["Inflation Rate (2022)"] / inflation_target_year_df["Mean Inflation"]) * 100), 0)

# filter rows that experienced greater than mean inflation
inflation_target_year_df = inflation_target_year_df[inflation_target_year_df["2022 Inflation as Percent of Mean Inflation (20 years)"] > 300]

display(inflation_target_year_df.head())
# Out:
#                       latitude  longitude  Inflation Rate (2022)  \
# country
# Antigua and Barbuda  17.060816 -61.796428               7.531078
# Austria              47.516231  14.550072               8.546870
# Bahamas              25.034280 -77.396280               5.605406
# Belgium              50.503887   4.469936               9.597512
# Belize               17.189877 -88.497650               6.276893
#
#                      Mean Inflation  \
# country
# Antigua and Barbuda        1.791956
# Austria                    2.370011
# Bahamas                    1.857542
# Belgium                    2.238289
# Belize                     1.275166
#
#                      2022 Inflation as Percent of Mean Inflation (20 years)
# country
# Antigua and Barbuda                                              420.0
# Austria                                                          361.0
# Bahamas                                                          302.0
# Belgium                                                          429.0
# Belize                                                           492.0

# %%
# describe last 20 years of inflation data
stats_df = inflation_target_year_df.iloc[:,-3]
summary_stats = stats_df.describe(include="all")
print(summary_stats)

# fine outliers visually
plt.boxplot(inflation_target_year_df["Inflation Rate (2022)"])
# Out:
# count     75.000000
# mean      12.699018
# std       21.014554
# min        2.497703
# 25%        6.118058
# 50%        8.002800
# 75%       12.167088
# max      171.205491
# Name: Inflation Rate (2022), dtype: float64
# {'whiskers': [<matplotlib.lines.Line2D at 0x164705e5300>,
#   <matplotlib.lines.Line2D at 0x164705e55a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x164705e5840>,
#   <matplotlib.lines.Line2D at 0x164705e5ae0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x164705e5060>],
#  'medians': [<matplotlib.lines.Line2D at 0x164705e5d80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x164705e6020>],
#  'means': []}

# %% [markdown]
# data visualization

# %%
map = inflation_target_year_df.hvplot.points(
    "longitude",
    "latitude",
    geo=True,
    tiles="CartoLight",
    xlabel="longitude",
    ylabel="latitude",
    frame_width=600,
    frame_height=400,
    color="red",
    line_color="black",
    title="Countries Experiencing Greater Than 300% 10-Year Mean Inflation in 2022",
    hover_cols=["country", "Inflation Rate (2022)"]
)

hvplot.save(map, "high_inflation_world_map.html")

map
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1026', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (country,Inflation Rate (2022))

# %% [markdown]
# ### Interactive Map

# %% [markdown]
# calculations and wide to long dataframe manipulation

# %%
# change to long (vs wide) df using melt
display(combined_df.head())

# create df
long_combined_df = combined_df

#reset index
long_combined_df.reset_index(inplace=True)

#list of columns
years = long_combined_df.columns.values.tolist()

# attributed resource: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.melt.html
long_combined_df = long_combined_df.melt(id_vars=["country", "latitude", "longitude"], value_vars=years, ignore_index=True)

# rename column
long_combined_df.rename(columns={"variable":"year", "value":"inflation rate"}, inplace=True)

# drop NaN rows
long_combined_df.dropna(axis=0, inplace=True)

# sort in descending order for map
long_combined_df.sort_values(by=["year"], ascending=False, inplace=True)

display(long_combined_df.head())

# stats to inform clim
long_combined_df["inflation rate"].hvplot.box(ylim=(-30,30))
# Out:
#                  latitude   longitude  1960  1961  1962  1963  1964  1965  \
# country
# Afghanistan     33.939110   67.709953   NaN   NaN   NaN   NaN   NaN   NaN
# Albania         41.153332   20.168331   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria         28.033886    1.659626   NaN   NaN   NaN   NaN   NaN   NaN
# American Samoa -14.270972 -170.132217   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra         42.546245    1.601554   NaN   NaN   NaN   NaN   NaN   NaN
#
#                 1966  1967  ...      2013      2014      2015      2016  \
# country                     ...
# Afghanistan      NaN   NaN  ...  7.385772  4.673996 -0.661709  4.383892
# Albania          NaN   NaN  ...  1.937621  1.625865  1.896174  1.275432
# Algeria          NaN   NaN  ...  3.254239  2.916927  4.784447  6.397695
# American Samoa   NaN   NaN  ...       NaN       NaN       NaN       NaN
# Andorra          NaN   NaN  ...       NaN       NaN       NaN       NaN
#
#                     2017      2018      2019      2020      2021      2022
# country
# Afghanistan     4.975952  0.626149  2.302373       NaN       NaN       NaN
# Albania         1.986661  2.028060  1.411091  1.620887  2.041472  6.725203
# Algeria         5.591116  4.269990  1.951768  2.415131  7.226063  9.265516
# American Samoa       NaN       NaN       NaN       NaN       NaN       NaN
# Andorra              NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 65 columns]
#              country   latitude  longitude  year  inflation rate
# 13292       Zimbabwe -19.015438  29.154857  2022      104.705171
# 13163          Haiti  18.971187 -72.285215  2022       33.983932
# 13161  Guinea-Bissau  11.803749 -15.180413  2022        9.393839
# 13160         Guinea   9.945587  -9.696645  2022       10.493041
# 13159      Guatemala  15.783471 -90.230759  2022        6.885128
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('index', 779), ('inflation rate', 779), ('inflation_rate', 0)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('index', 779), ('inflation rate', 779), ('inflation_rate', 0)
# :BoxWhisker   (inflation rate)

# %% [markdown]
# data visualization

# %%
# attributed source: https://geoviews.org/user_guide/Working_with_Bokeh.html
# attributed source: https://geoviews.org/user_guide/Annotators.html
# Create an interactive map grouped by year

# define points for map
# kdims - key dimensions relate to the axis
# vdims - value dims do not relate to the axis but rather to color or size
map_points = gv.Points(long_combined_df, kdims=["longitude", "latitude"], vdims=["year", "inflation rate"])

# groupby and sort
map_points_grouped_by_year = map_points.groupby("year")

# map code
interactive_map = gv.tile_sources.CartoLight * map_points_grouped_by_year.opts(
    opts.Points(width=600,
                height=400,
                tools=["hover"],
                color="inflation rate",
                colorbar=True,
                size=8,
                color_levels=7,
                colorbar_opts={"title":"Inflation Rate %"},
                cmap=["#00ccff", "#b3f0ff", "#ffffff", "#ff9980", "#ff3300", "#991f00", "#330a00"],
                clim=(-10,25),
                line_color="black",
                title="World Inflation by Country 1960-2022")
)

#save
hvplot.save(interactive_map, "world_inflation_interactive_map.html")

interactive_map
# Out:
# :HoloMap   [year]
#    :Overlay
#       .WMTS.I   :WMTS   [Longitude,Latitude]
#       .Points.I :Points   [longitude,latitude]   (year,inflation rate)
